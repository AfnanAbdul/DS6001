# %%
import numpy as np
import pandas as pd
import psycopg
from sqlalchemy import create_engine
import dotenv
import os
#import sqlite3

# %%
nba = pd.read_csv('ASA All NBA Raw Data.csv', low_memory=False)

# %%
pd.set_option('display.max_rows', 81)
nba.head(3).T
# Out:
#                                                                               0  \
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                            Corey Kispert
# player_id                                                             kispeco01
# starter                                                                       1
# mp                                                                        32:30
# fg                                                                            6
# fga                                                                           9
# fg_pct                                                                    0.667
# fg3                                                                           4
# fg3a                                                                          6
# fg3_pct                                                                   0.667
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           0
# drb                                                                           1
# trb                                                                           1
# ast                                                                           1
# stl                                                                           2
# blk                                                                           0
# tov                                                                           2
# pf                                                                            2
# pts                                                                          16
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.889
# efg_pct                                                                   0.889
# fg3a_per_fga_pct                                                          0.667
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     0.0
# drb_pct                                                                     3.3
# trb_pct                                                                     1.8
# ast_pct                                                                     4.0
# stl_pct                                                                     3.1
# blk_pct                                                                     0.0
# tov_pct                                                                    18.2
# usg_pct                                                                    15.6
# off_rtg                                                                     133
# def_rtg                                                                     113
# bpm                                                                         3.1
# season                                                                     2022
# minutes                                                                    32.5
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       23.75
# FDP                                                                        22.7
# SDP                                                                       24.75
# DKP_per_minute                                                0.730769230769231
# FDP_per_minute                                                0.698461538461538
# SDP_per_minute                                                0.761538461538461
# pf_per_minute                                                          0.061538
# ts                                                                          9.0
# last_60_minutes_per_game_starting                                     31.716667
# last_60_minutes_per_game_bench                                        22.017778
# PG%                                                                         1.0
# SG%                                                                        36.0
# SF%                                                                        60.0
# PF%                                                                         4.0
# C%                                                                          0.0
# active_position_minutes                                               46.253586
#
#                                                                               1  \
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                               Kyle Kuzma
# player_id                                                             kuzmaky01
# starter                                                                       1
# mp                                                                        30:16
# fg                                                                            2
# fga                                                                           7
# fg_pct                                                                    0.286
# fg3                                                                           0
# fg3a                                                                          3
# fg3_pct                                                                     0.0
# ft                                                                            1
# fta                                                                           1
# ft_pct                                                                      1.0
# orb                                                                           0
# drb                                                                           7
# trb                                                                           7
# ast                                                                           5
# stl                                                                           1
# blk                                                                           0
# tov                                                                           7
# pf                                                                            3
# pts                                                                           5
# plus_minus                                                                   10
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.336
# efg_pct                                                                   0.286
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                           0.143
# orb_pct                                                                     0.0
# drb_pct                                                                    24.7
# trb_pct                                                                    13.9
# ast_pct                                                                    18.5
# stl_pct                                                                     1.7
# blk_pct                                                                     0.0
# tov_pct                                                                    48.5
# usg_pct                                                                    22.0
# off_rtg                                                                      55
# def_rtg                                                                     107
# bpm                                                                       -15.5
# season                                                                     2022
# minutes                                                               30.266667
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       19.75
# FDP                                                                        16.9
# SDP                                                                       17.25
# DKP_per_minute                                                0.652533039647577
# FDP_per_minute                                                0.558370044052863
# SDP_per_minute                                                0.569933920704846
# pf_per_minute                                                          0.099119
# ts                                                                         7.44
# last_60_minutes_per_game_starting                                        34.324
# last_60_minutes_per_game_bench                                        18.475954
# PG%                                                                         0.0
# SG%                                                                         0.0
# SF%                                                                         4.0
# PF%                                                                        85.0
# C%                                                                         11.0
# active_position_minutes                                                52.15259
#
#                                                                               2
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                 Kentavious Caldwell-Pope
# player_id                                                             caldwke01
# starter                                                                       1
# mp                                                                        25:26
# fg                                                                            3
# fga                                                                           7
# fg_pct                                                                    0.429
# fg3                                                                           1
# fg3a                                                                          3
# fg3_pct                                                                   0.333
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           1
# drb                                                                           4
# trb                                                                           5
# ast                                                                           2
# stl                                                                           1
# blk                                                                           0
# tov                                                                           1
# pf                                                                            0
# pts                                                                           7
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                      0.5
# efg_pct                                                                     0.5
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     5.4
# drb_pct                                                                    16.8
# trb_pct                                                                    11.8
# ast_pct                                                                     9.4
# stl_pct                                                                     2.0
# blk_pct                                                                     0.0
# tov_pct                                                                    12.5
# usg_pct                                                                    14.5
# off_rtg                                                                     106
# def_rtg                                                                     110
# bpm                                                                        -3.8
# season                                                                     2022
# minutes                                                               25.433333
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       18.25
# FDP                                                                        18.0
# SDP                                                                       18.75
# DKP_per_minute                                                0.717562254259502
# FDP_per_minute                                                0.707732634338139
# SDP_per_minute                                                0.737221494102228
# pf_per_minute                                                               0.0
# ts                                                                          7.0
# last_60_minutes_per_game_starting                                      29.82029
# last_60_minutes_per_game_bench                                        16.051693
# PG%                                                                         0.0
# SG%                                                                        32.0
# SF%                                                                        67.0
# PF%                                                                         0.0
# C%                                                                          0.0
# active_position_minutes                                               47.021807

# %% [markdown]
# ## Database Normalization
# ### First normal form:
#
# 1. **All tables must have a primary key**: In this table, `game_id` and `player_id` together are unique on every row, and so they form primary key.
#
# 2. **All the data must be atomic**: Inactives is non-atomic.
#
# 3. **No repeating groups problem**: We can't solve the non-atomicity problem by creating separate columns if this leads to arbitrary ordering language in the column names (for example, `Inactive1`, `Inactive2`, etc.) and if it leads to a lot of missing data (there would be an `Inactive7` which would be missing any time a team has less than 7 inactive players).

# %%
nba = nba.drop(['Inactives'], axis=1)

# %% [markdown]
# ### Functional Dependence
# Let X and Y be columns in a data table. Y is functionally dependent on X if each value of X has exactly one value of Y.
#
# That's pretty abstract. So here are some guidelines that help me:
#
# 1. This use of "function" is the exact same as the concept of a function from algebra and pre-calculus. A correspondence f(x)=y is a function if each value of x has only one associated value of y.
#
# 2. X is either a primary key, or something that should be a primary key in another table.
#
# For example, `game_date` (Y) is functionally dependent on `game_id` (X) because one `game_id` takes place on exactly one date.
#
# ### Second normal form:
# In this table the primary key is a superkey consisting of two columns: `game_id` and `player_id`.
#
# 2NF is violated if any columns are functionally dependent on part of the primary key but not the entire primary key. This can only happen if the primary key is a superkey.

# %%
# you remove these tables and put them on a seprate table
# now this is our second table in our database
games = nba[['game_id', 'game_date', 'OT', 'season']].drop_duplicates()
games
# Out:
#              game_id   game_date  OT  season
# 0       202202170BRK  2022-02-17   0    2022
# 26      202202170CHO  2022-02-17   2    2022
# 48      202202170LAC  2022-02-17   0    2022
# 71      202202170MIL  2022-02-17   0    2022
# 95      202202170NOP  2022-02-17   0    2022
# ...              ...         ...  ..     ...
# 108259  202001080GSW  2020-01-08   0    2020
# 108887  202008020HOU  2020-08-02   0    2020
# 109683  201911060HOU  2019-11-06   0    2020
# 110125  201912250GSW  2019-12-25   0    2020
# 110643  202002200GSW  2020-02-20   0    2020
#
# [3197 rows x 4 columns]

# %%
players = nba[['player_id', 'player']].drop_duplicates()
players
# Out:
#         player_id                    player
# 0       kispeco01             Corey Kispert
# 1       kuzmaky01                Kyle Kuzma
# 2       caldwke01  Kentavious Caldwell-Pope
# 3        netora01                 Raul Neto
# 4       bryanth01             Thomas Bryant
# ...           ...                       ...
# 109702  frazimi01           Michael Frazier
# 110441  howarwi01            William Howard
# 110913  mbahalu01          Luc Mbah a Moute
# 111399  bowmaky01                 Ky Bowman
# 112021  pargoje01              Jeremy Pargo
#
# [812 rows x 2 columns]

# %%
nba = nba.drop(['game_date', 'OT', 'season', 'player'], axis=1)

# %% [markdown]
# ### Third normal form:
# 3NF is violated if there are "transitive dependencies", that is, functional dependence between columns when neither column is part of the primary key.

# %%
nba.columns
# Out:
# Index(['game_id', 'H_A', 'Team_Abbrev', 'Team_Score', 'Team_pace',
#        'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct', 'Team_ft_rate',
#        'Team_off_rtg', 'Opponent_Abbrev', 'Opponent_Score', 'Opponent_pace',
#        'Opponent_efg_pct', 'Opponent_tov_pct', 'Opponent_orb_pct',
#        'Opponent_ft_rate', 'Opponent_off_rtg', 'player_id', 'starter', 'mp',
#        'fg', 'fga', 'fg_pct', 'fg3', 'fg3a', 'fg3_pct', 'ft', 'fta', 'ft_pct',
#        'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts',
#        'plus_minus', 'did_not_play', 'is_inactive', 'ts_pct', 'efg_pct',
#        'fg3a_per_fga_pct', 'fta_per_fga_pct', 'orb_pct', 'drb_pct', 'trb_pct',
#        'ast_pct', 'stl_pct', 'blk_pct', 'tov_pct', 'usg_pct', 'off_rtg',
#        'def_rtg', 'bpm', 'minutes', 'double_double', 'triple_double', 'DKP',
#        'FDP', 'SDP', 'DKP_per_minute', 'FDP_per_minute', 'SDP_per_minute',
#        'pf_per_minute', 'ts', 'last_60_minutes_per_game_starting',
#        'last_60_minutes_per_game_bench', 'PG%', 'SG%', 'SF%', 'PF%', 'C%',
#        'active_position_minutes'],
#       dtype='object')

# %%
team_game = nba[['game_id', 'Team_Abbrev', 'Team_Score',
    'Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev']].drop_duplicates()
nba.drop(['Team_Score','Team_pace', 'Team_efg_pct', 'Team_tov_pct', 'Team_orb_pct',
       'Team_ft_rate', 'Team_off_rtg', 'Opponent_Abbrev', 'Opponent_Score',
       'Opponent_pace', 'Opponent_efg_pct', 'Opponent_tov_pct',
       'Opponent_orb_pct', 'Opponent_ft_rate', 'Opponent_off_rtg'], axis=1)
player_game = nba

# %%
# make all cols lower case for postgres
player_game.columns = [x.lower().replace('%', '_pct') for x in player_game.columns]
team_game.columns = [x.lower().replace('%', '_pct') for x in team_game.columns]
players.columns = [x.lower().replace('%', '_pct') for x in players.columns]
games.columns = [x.lower().replace('%', '_pct') for x in games.columns]

# %%
player_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112123 entries, 0 to 112122
# Data columns (total 76 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   game_id                            112123 non-null  object
#  1   h_a                                112123 non-null  object
#  2   team_abbrev                        112123 non-null  object
#  3   team_score                         112123 non-null  int64
#  4   team_pace                          112123 non-null  float64
#  5   team_efg_pct                       112123 non-null  float64
#  6   team_tov_pct                       112123 non-null  float64
#  7   team_orb_pct                       112123 non-null  float64
#  8   team_ft_rate                       112123 non-null  float64
#  9   team_off_rtg                       112123 non-null  float64
#  10  opponent_abbrev                    112123 non-null  object
#  11  opponent_score                     112123 non-null  int64
#  12  opponent_pace                      112123 non-null  float64
#  13  opponent_efg_pct                   112123 non-null  float64
#  14  opponent_tov_pct                   112123 non-null  float64
#  15  opponent_orb_pct                   112123 non-null  float64
#  16  opponent_ft_rate                   112123 non-null  float64
#  17  opponent_off_rtg                   112123 non-null  float64
#  18  player_id                          112123 non-null  object
#  19  starter                            112123 non-null  int64
#  20  mp                                 112123 non-null  object
#  21  fg                                 112123 non-null  int64
#  22  fga                                112123 non-null  int64
#  23  fg_pct                             112123 non-null  float64
#  24  fg3                                112123 non-null  int64
#  25  fg3a                               112123 non-null  int64
#  26  fg3_pct                            112123 non-null  float64
#  27  ft                                 112123 non-null  int64
#  28  fta                                112123 non-null  int64
#  29  ft_pct                             112123 non-null  float64
#  30  orb                                112123 non-null  int64
#  31  drb                                112123 non-null  int64
#  32  trb                                112123 non-null  int64
#  33  ast                                112123 non-null  int64
#  34  stl                                112123 non-null  int64
#  35  blk                                112123 non-null  int64
#  36  tov                                112123 non-null  int64
#  37  pf                                 112123 non-null  int64
#  38  pts                                112123 non-null  int64
#  39  plus_minus                         112123 non-null  int64
#  40  did_not_play                       112123 non-null  int64
#  41  is_inactive                        112123 non-null  int64
#  42  ts_pct                             112123 non-null  float64
#  43  efg_pct                            112123 non-null  float64
#  44  fg3a_per_fga_pct                   112123 non-null  float64
#  45  fta_per_fga_pct                    112123 non-null  float64
#  46  orb_pct                            112123 non-null  float64
#  47  drb_pct                            112123 non-null  float64
#  48  trb_pct                            112123 non-null  float64
#  49  ast_pct                            112123 non-null  float64
#  50  stl_pct                            112123 non-null  float64
#  51  blk_pct                            112123 non-null  float64
#  52  tov_pct                            112123 non-null  float64
#  53  usg_pct                            112123 non-null  float64
#  54  off_rtg                            112123 non-null  int64
#  55  def_rtg                            112123 non-null  int64
#  56  bpm                                112123 non-null  float64
#  57  minutes                            112123 non-null  float64
#  58  double_double                      112123 non-null  int64
#  59  triple_double                      112123 non-null  int64
#  60  dkp                                112123 non-null  float64
#  61  fdp                                112123 non-null  float64
#  62  sdp                                112123 non-null  float64
#  63  dkp_per_minute                     92725 non-null   object
#  64  fdp_per_minute                     92725 non-null   object
#  65  sdp_per_minute                     92725 non-null   object
#  66  pf_per_minute                      92724 non-null   float64
#  67  ts                                 112123 non-null  float64
#  68  last_60_minutes_per_game_starting  109403 non-null  float64
#  69  last_60_minutes_per_game_bench     109403 non-null  float64
#  70  pg_pct                             111976 non-null  float64
#  71  sg_pct                             111976 non-null  float64
#  72  sf_pct                             111976 non-null  float64
#  73  pf_pct                             111976 non-null  float64
#  74  c_pct                              111976 non-null  float64
#  75  active_position_minutes            97003 non-null   float64
# dtypes: float64(42), int64(25), object(9)
# memory usage: 65.0+ MB

# %%
team_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6394 entries, 0 to 112112
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   game_id          6394 non-null   object
#  1   team_abbrev      6394 non-null   object
#  2   team_score       6394 non-null   int64
#  3   team_pace        6394 non-null   float64
#  4   team_efg_pct     6394 non-null   float64
#  5   team_tov_pct     6394 non-null   float64
#  6   team_orb_pct     6394 non-null   float64
#  7   team_ft_rate     6394 non-null   float64
#  8   team_off_rtg     6394 non-null   float64
#  9   opponent_abbrev  6394 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 549.5+ KB

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 812 entries, 0 to 112021
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   player_id  812 non-null    object
#  1   player     812 non-null    object
# dtypes: object(2)
# memory usage: 19.0+ KB

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3197 entries, 0 to 110643
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   game_id    3197 non-null   object
#  1   game_date  3197 non-null   object
#  2   ot         3197 non-null   int64
#  3   season     3197 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 124.9+ KB

# %% [raw]
# install dbdocs, dbdocs code for when installed (you migh need to install node.js)
#
# Joining:
# > many-to-one
# < one-to-many
# <> many-to-many (bad)
# - one-to-one
#
# X and Y are tables:
# "One X goes with (A) Y"
# "One Y goes with (B) X"
# then the relationship is A to B
#
# one game goes with MANY players in the game
# one row in player_game mathces to ONE row in the games table
#
# Many to one
#
# Ref: G.game_id < PG.game_id
#
# ER diagram:
# ```bash
# dbdocs login
# dbdocs build <path to your dbml file>/nba_db.dbml
# ```

# %% [markdown]
# ```bash
# (db_env) afnan@Afnans-Air M06 % dbdocs build nba_db.dbml
# ✔ Parsing file content
# ⚠ Project 'NBA' is public, consider setting password or restricting access to it
# ✔ Done. Visit: https://dbdocs.io/AfnanAbdul/NBA
#
# ℹ Thanks for using dbdocs! We'd love to hear your feedback: https://form.jotform.com/200962053361448
# ```

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

# %%
# connect to postgres server
dbserver = psycopg.connect(
    user='postgres', 
    password=POSTGRES_PASSWORD, 
    host='localhost',
    port = '5432'
)
dbserver.autocommit = True

# %%
# create NBA database
cursor = dbserver.cursor()
try:
    cursor.execute('CREATE DATABASE nba')
except:
    cursor.execute('DROP DATABASE nba')
    cursor.execute('CREATE DATABASE nba')

# %%
# upload NBA dfs to NBA database
dbms = 'postgresql'
connector = 'psycopg'
user = 'postgres'
pw = POSTGRES_PASSWORD
host = 'localhost'
port = '5432'
database = 'nba'
engine_string = f'{dbms}+{connector}://{user}:{pw}@{host}:{port}/{database}'
engine_string
# Out:
# 'postgresql+psycopg://postgres:bikrys-1nyvma-qykdUv@localhost:5432/nba'

# %%
engine = create_engine(engine_string)

# %%
player_game.to_sql('player_games', con=engine, chunksize=1000, if_exists='replace', index=False)
# Out:
# -113

# %%
player_game.shape
# Out:
# (112123, 76)

# %%
pd.read_sql_query('SELECT * FROM player_games', con=engine).shape
# Out:
# (112123, 76)

# %%
team_game.to_sql('team_game', con=engine, chunksize=1000, if_exists='replace', index=False)
players.to_sql('players', con=engine, chunksize=1000, if_exists='replace', index=False)
games.to_sql('games', con=engine, chunksize=1000, if_exists='replace', index=False)
# Out:
# -4

# %%
team_game.shape
players.shape
games.shape
# Out:
# (3197, 4)

# %%
pd.read_sql_query('SELECT * FROM team_game', con=engine).shape
pd.read_sql_query('SELECT * FROM players', con=engine).shape
pd.read_sql_query('SELECT * FROM games', con=engine).shape
# Out:
# (3197, 4)

# %%
myquery = '''
SELECT *
FROM games
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#            game_id   game_date  ot  season
# 0     202202170BRK  2022-02-17   0    2022
# 1     202202170CHO  2022-02-17   2    2022
# 2     202202170LAC  2022-02-17   0    2022
# 3     202202170MIL  2022-02-17   0    2022
# 4     202202170NOP  2022-02-17   0    2022
# ...            ...         ...  ..     ...
# 3192  202001080GSW  2020-01-08   0    2020
# 3193  202008020HOU  2020-08-02   0    2020
# 3194  201911060HOU  2019-11-06   0    2020
# 3195  201912250GSW  2019-12-25   0    2020
# 3196  202002200GSW  2020-02-20   0    2020
#
# [3197 rows x 4 columns]

# %%
myquery = '''
SELECT *
FROM player_games
WHERE pts > 60
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#         game_id h_a team_abbrev  team_score  team_pace  team_efg_pct  \
# 0  202101030GSW   H         GSW         137      107.2         0.631
# 1  202001200POR   H         POR         129      100.3         0.510
# 2  202001200POR   H         POR         129      100.3         0.510
# 3  202008110DAL   A         POR         134      104.3         0.546
# 4  202008110DAL   A         POR         134      104.3         0.546
#
#    team_tov_pct  team_orb_pct  team_ft_rate  team_off_rtg  ... pf_per_minute  \
# 0          12.7          28.2         0.295         127.8  ...      0.000000
# 1           9.6          22.6         0.270         116.4  ...      0.022157
# 2           9.6          22.6         0.270         116.4  ...      0.022157
# 3           6.7          27.3         0.276         128.5  ...      0.048682
# 4           6.7          27.3         0.276         128.5  ...      0.048682
#
#       ts  last_60_minutes_per_game_starting  last_60_minutes_per_game_bench  \
# 0  39.36                          32.836667                       16.089368
# 1  44.04                          35.911905                       20.859681
# 2  44.04                          35.911905                       20.859681
# 3  39.92                          41.463889                       24.084590
# 4  39.92                          41.463889                       24.084590
#
#    pg_pct  sg_pct  sf_pct  pf_pct c_pct  active_position_minutes
# 0    82.0    18.0     0.0     0.0   0.0                51.151069
# 1   100.0     0.0     0.0     0.0   0.0               221.003792
# 2   100.0     0.0     0.0     0.0   0.0               221.003792
# 3   100.0     0.0     0.0     0.0   0.0               205.012500
# 4   100.0     0.0     0.0     0.0   0.0               205.012500
#
# [5 rows x 76 columns]
