# %% [markdown]
# # Lab Report 4: Using APIs in Python
# ## Name: Afnan Alabdulwahab
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Problem 0
# Import the following libraries:

# %%
import numpy as np
import pandas as pd
import requests
import json
import os
import dotenv
import sys
sys.tracebacklimit = 0 # turn off the error tracebacks

# %% [markdown]
# ## Problem 1

# %% [markdown]
# To obtain access to the Genius API, I followed several key steps as outlined in the documentation. First, I navigated to the API Client Management Page where I initiated the creation of a new API client. This required me to sign up for a free Genius account. After signing up and logging in, I proceeded to the API registration page. Here, I needed to provide some basic information about the API client I was creating.
#
# I followed suit and named my client "Collab" and used the URL for the UVA Collab main page (https://collab.its.virginia.edu/portal?containerLogin=true) for both the Application Website URL and the Redirect URL. After submitting the form with these details, Genius provided me with the necessary credentials: the **client_id**, **client_secret**, and **client_access_token**.

# %% [markdown]
# ## Problem 2
# ## Loading Environment Variables with dotenv
# `dotenv.load_dotenv()` loads environment variables from a `.env` file into the environment. The `.env` file contains key-value pairs for the Genius API credentials I obtained in the previous step
# The next lines of code access the environment variables id, secret, and accesstoken and store their values in the respective Python variables **genius_id**, **genius_secret**, and **genius_accesstoken**. The `os.getenv()` function retrieves the value of the specified environment variable, allowing us to use these credentials in our API requests without hard-coding them into the script.

# %%
dotenv.load_dotenv()

genius_id = os.getenv('id')
genius_secret = os.getenv('secret')
genius_accesstoken = os.getenv('accesstoken')

# %% [markdown]
# ## Problem 3

# %% [markdown]
# First, I get the user agent, using 'https://httpbin.org', to include in the `headers` parameter for HTTP and API requests.

# %%
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']
headers = { 'User-agent': useragent }

# %% [markdown]
# ## Setting Up API Root and Endpoint:
# * root = 'https://api.genius.com': This variable defines the base URL (root) for accessing the Genius API.
# * endpoint = '/search': This variable specifies the specific endpoint (/search) within the Genius API. The /search endpoint is used for searching across Genius's database.
#
# ## Making the API Request:
# I use the `requests` library to send a request to the Genius API
# * root + endpoint: Concatenates the base URL (root) and the endpoint to form the complete URL (https://api.genius.com/search) for the API request.
# * headers=headers: headers contains user agent info
# * params=params: Sends the parameters defined in the params dictionary (access_token and q (search term, Bob Dylan, in this case)) as part of the request.

# %%
root = 'https://api.genius.com'
endpoint = '/search'
params = {
    'access_token': genius_accesstoken,
    'q': 'Bob Dylan'
}
r = requests.get(root + endpoint, headers=headers, params=params)
r
# Out:
# <Response [200]>

# %% [markdown]
# To extract the JSON data, I used the `.text` attribute and the json.loads() function. Then, I navigated the JSON structure to find the portion that shows the API endpoint for Bob Dylan.

# %%
bobdylan_json = json.loads(r.text)
bobdylan_json['response']['hits'][0]['result']['primary_artist']
# Out:
# {'api_path': '/artists/181',
#  'header_image_url': 'https://images.genius.com/e87fb11dd7f33cc7fd1a8915ad36f7c9.1000x667x1.png',
#  'id': 181,
#  'image_url': 'https://images.genius.com/571780cc8959528e8166e5894ab13d6f.1000x1000x1.jpg',
#  'is_meme_verified': False,
#  'is_verified': False,
#  'name': 'Bob Dylan',
#  'url': 'https://genius.com/artists/Bob-dylan'}

# %% [markdown]
# Here, I extracted Bob Dylan's ID and API endpoint path from the JSON data.

# %%
bob_dylan_id = bobdylan_json['response']['hits'][0]['result']\
['primary_artist']['id']
bob_dylan_api_path = bobdylan_json['response']['hits'][0]['result']\
['primary_artist']['api_path']
print(f"Bob Dylan's ID: {bob_dylan_id}")
print(f"Bob Dylan's API Endpoint Path: {bob_dylan_api_path}")
# Out:
# Bob Dylan's ID: 181
# Bob Dylan's API Endpoint Path: /artists/181

# %% [markdown]
# ## Problem 4

# %% [markdown]
# <img src="img.jpg" width="600">
#
# Using Bob Dylan's API endpoint path with `/songs` to request the 20 most popular Bob Dylan songs. I used to documentation to find the parameters specifications for the `/songs` request.
#
# ## Defining Parameters for the Request:
# * 'access_token': This parameter is set to genius_accesstoken, holding the access token required for authenticating and accessing the Genius API.
# * 'sort': This parameter specifies how the results should be sorted. In this case, it is set to 'popularity'.
# * 'per_page': This parameter specifies the number of results per page to be returned by the API. Here, it is set to 20.

# %%
endpoint = bob_dylan_api_path + '/songs'
params = {
    'access_token': genius_accesstoken,
    'sort': 'popularity',
    'per_page': 20
         }
r = requests.get(root + endpoint, headers=headers, params=params)
r
# Out:
# <Response [200]>

# %% [markdown]
# Used `json.loads()` on the `.text` attribute of the output `r` to register the data in Python's memory.

# %%
bdsongs_json = json.loads(r.text)

# %% [markdown]
# Then, used `pd.json_normalize()` on the list `bdsongs_json` to store every feature in the data in a separate column and save the data as a `pandas` dataframe.

# %%
bdsongs_df = pd.json_normalize(bdsongs_json, record_path = \
                               ['response', 'songs'])
bdsongs_df
# Out:
#     annotation_count        api_path                     artist_names  \
# 0                 15    /songs/96286                   USA For Africa
# 1                 12    /songs/79424                        Bob Dylan
# 2                  1    /songs/68146                            Adele
# 3                 18    /songs/62605                        Bob Dylan
# 4                128  /songs/5393247                        Bob Dylan
# 5                  7   /songs/103982  Guns N' Roses (Ft. ​The Waters)
# 6                 15    /songs/98664                        Bob Dylan
# 7                 28    /songs/54784                        Bob Dylan
# 8                 10    /songs/84846                        Bob Dylan
# 9                 10    /songs/63341      The Jimi Hendrix Experience
# 10                30    /songs/87402                        Bob Dylan
# 11                10    /songs/79749                        Bob Dylan
# 12                20      /songs/224                        Bob Dylan
# 13                36   /songs/105186                        Bob Dylan
# 14                22    /songs/75446                        Bob Dylan
# 15                14   /songs/154239                    Darius Rucker
# 16                79    /songs/92350                        Bob Dylan
# 17                34   /songs/118799                        Bob Dylan
# 18                51    /songs/75463                        Bob Dylan
# 19                 6   /songs/199531                        Bob Dylan
#
#                                            full_title  \
# 0                  We Are the World by USA For Africa
# 1                    Blowin' in the Wind by Bob Dylan
# 2                      Make You Feel My Love by Adele
# 3          The Times They Are A-Changin' by Bob Dylan
# 4                       Murder Most Foul by Bob Dylan
# 5   Knockin’ on Heaven’s Door by Guns N' Roses (Ft...
# 6               All Along the Watchtower by Bob Dylan
# 7                   Like a Rolling Stone by Bob Dylan
# 8      Don't Think Twice, It's All Right by Bob Dylan
# 9   All Along the Watchtower by The Jimi Hendrix E...
# 10                             Hurricane by Bob Dylan
# 11                 Make You Feel My Love by Bob Dylan
# 12           Subterranean Homesick Blues by Bob Dylan
# 13            A Hard Rain's A-Gonna Fall by Bob Dylan
# 14                    Mr. Tambourine Man by Bob Dylan
# 15                       Wagon Wheel by Darius Rucker
# 16                        Desolation Row by Bob Dylan
# 17                    Tangled Up in Blue by Bob Dylan
# 18  It's Alright, Ma (I'm Only Bleeding) by Bob Dylan
# 19             Knockin’ on Heaven’s Door by Bob Dylan
#
#                            header_image_thumbnail_url  \
# 0   https://images.genius.com/c21fb053cb43a6a35e31...
# 1   https://images.genius.com/84e1705bc64495197216...
# 2   https://images.genius.com/becead7e44b8202463f0...
# 3   https://images.genius.com/e00b4dcec135cb5ab3ee...
# 4   https://images.genius.com/7fbaf838ffdf99315408...
# 5   https://images.genius.com/cb2614550098bf753ab3...
# 6   https://images.genius.com/f727dfc7b28942c59cd6...
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...
# 8   https://images.genius.com/84e1705bc64495197216...
# 9   https://images.genius.com/892e94dacb1ac51070e5...
# 10  https://images.genius.com/2ae7853a0fc26b8340ce...
# 11  https://images.genius.com/cd0a26733cc459710d09...
# 12  https://images.genius.com/2fb972dceb4a8e726359...
# 13  https://images.genius.com/84e1705bc64495197216...
# 14  https://images.genius.com/2fb972dceb4a8e726359...
# 15  https://images.genius.com/71f204d1ae373a8a004a...
# 16  https://images.genius.com/b67cf8e6822a6ec84ea9...
# 17  https://images.genius.com/9146ba54ed06288f10b2...
# 18  https://images.genius.com/2fb972dceb4a8e726359...
# 19  https://images.rapgenius.com/328b31b5fe67895fa...
#
#                                      header_image_url       id  \
# 0   https://images.genius.com/c21fb053cb43a6a35e31...    96286
# 1   https://images.genius.com/84e1705bc64495197216...    79424
# 2   https://images.genius.com/becead7e44b8202463f0...    68146
# 3   https://images.genius.com/e00b4dcec135cb5ab3ee...    62605
# 4   https://images.genius.com/7fbaf838ffdf99315408...  5393247
# 5   https://images.genius.com/cb2614550098bf753ab3...   103982
# 6   https://images.genius.com/f727dfc7b28942c59cd6...    98664
# 7   https://images.genius.com/5de9704b9bd8773ddbcb...    54784
# 8   https://images.genius.com/84e1705bc64495197216...    84846
# 9   https://images.genius.com/892e94dacb1ac51070e5...    63341
# 10  https://images.genius.com/2ae7853a0fc26b8340ce...    87402
# 11  https://images.genius.com/cd0a26733cc459710d09...    79749
# 12  https://images.genius.com/2fb972dceb4a8e726359...      224
# 13  https://images.genius.com/84e1705bc64495197216...   105186
# 14  https://images.genius.com/2fb972dceb4a8e726359...    75446
# 15  https://images.genius.com/71f204d1ae373a8a004a...   154239
# 16  https://images.genius.com/b67cf8e6822a6ec84ea9...    92350
# 17  https://images.genius.com/9146ba54ed06288f10b2...   118799
# 18  https://images.genius.com/2fb972dceb4a8e726359...    75463
# 19  https://images.rapgenius.com/328b31b5fe67895fa...   199531
#
#     lyrics_owner_id lyrics_state  \
# 0           4733728     complete
# 1             73267     complete
# 2             82481     complete
# 3             49202     complete
# 4           3360167     complete
# 5            168784     complete
# 6               779     complete
# 7                 7     complete
# 8            125524     complete
# 9             31298     complete
# 10           132320     complete
# 11             5307     complete
# 12                4     complete
# 13               16     complete
# 14            74226     complete
# 15            10380     complete
# 16           145715     complete
# 17             1850     complete
# 18            74226     complete
# 19           225680     complete
#
#                                                  path  ... stats.pageviews  \
# 0             /Usa-for-africa-we-are-the-world-lyrics  ...          650054
# 1                /Bob-dylan-blowin-in-the-wind-lyrics  ...          602584
# 2                 /Adele-make-you-feel-my-love-lyrics  ...          587443
# 3      /Bob-dylan-the-times-they-are-a-changin-lyrics  ...          524320
# 4                  /Bob-dylan-murder-most-foul-lyrics  ...          504643
# 5        /Guns-n-roses-knockin-on-heavens-door-lyrics  ...          499002
# 6          /Bob-dylan-all-along-the-watchtower-lyrics  ...          494230
# 7              /Bob-dylan-like-a-rolling-stone-lyrics  ...          461350
# 8    /Bob-dylan-dont-think-twice-its-all-right-lyrics  ...          419115
# 9   /The-jimi-hendrix-experience-all-along-the-wat...  ...          387166
# 10                        /Bob-dylan-hurricane-lyrics  ...          379277
# 11            /Bob-dylan-make-you-feel-my-love-lyrics  ...          368234
# 12      /Bob-dylan-subterranean-homesick-blues-lyrics  ...          321797
# 13        /Bob-dylan-a-hard-rains-a-gonna-fall-lyrics  ...          293462
# 14                /Bob-dylan-mr-tambourine-man-lyrics  ...          279360
# 15                  /Darius-rucker-wagon-wheel-lyrics  ...          269834
# 16                   /Bob-dylan-desolation-row-lyrics  ...          212399
# 17               /Bob-dylan-tangled-up-in-blue-lyrics  ...          211255
# 18  /Bob-dylan-its-alright-ma-im-only-bleeding-lyrics  ...          204037
# 19          /Bob-dylan-knockin-on-heavens-door-lyrics  ...          202411
#
#     primary_artist.api_path  \
# 0           /artists/370890
# 1              /artists/181
# 2             /artists/2300
# 3              /artists/181
# 4              /artists/181
# 5              /artists/637
# 6              /artists/181
# 7              /artists/181
# 8              /artists/181
# 9           /artists/634985
# 10             /artists/181
# 11             /artists/181
# 12             /artists/181
# 13             /artists/181
# 14             /artists/181
# 15           /artists/21867
# 16             /artists/181
# 17             /artists/181
# 18             /artists/181
# 19             /artists/181
#
#                       primary_artist.header_image_url primary_artist.id  \
# 0   https://images.genius.com/3fb2d9f68c911b547339...            370890
# 1   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 2   https://images.genius.com/87aa5d8c32965a10e0e7...              2300
# 3   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 4   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 5   https://images.genius.com/83c4b54659d674bd3778...               637
# 6   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 7   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 8   https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 9   https://images.genius.com/2631895179875ea7541b...            634985
# 10  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 11  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 12  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 13  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 14  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 15  https://images.genius.com/6a629cf1a4b6fec5b21a...             21867
# 16  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 17  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 18  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
# 19  https://images.genius.com/e87fb11dd7f33cc7fd1a...               181
#
#                              primary_artist.image_url  \
# 0   https://images.genius.com/3fb2d9f68c911b547339...
# 1   https://images.genius.com/571780cc8959528e8166...
# 2   https://images.genius.com/8a23ab928ccfce13accf...
# 3   https://images.genius.com/571780cc8959528e8166...
# 4   https://images.genius.com/571780cc8959528e8166...
# 5   https://images.genius.com/53ddc7640957b4279d9c...
# 6   https://images.genius.com/571780cc8959528e8166...
# 7   https://images.genius.com/571780cc8959528e8166...
# 8   https://images.genius.com/571780cc8959528e8166...
# 9   https://images.genius.com/ca64447350d06d6dc144...
# 10  https://images.genius.com/571780cc8959528e8166...
# 11  https://images.genius.com/571780cc8959528e8166...
# 12  https://images.genius.com/571780cc8959528e8166...
# 13  https://images.genius.com/571780cc8959528e8166...
# 14  https://images.genius.com/571780cc8959528e8166...
# 15  https://images.genius.com/6009b412250fcc9da909...
# 16  https://images.genius.com/571780cc8959528e8166...
# 17  https://images.genius.com/571780cc8959528e8166...
# 18  https://images.genius.com/571780cc8959528e8166...
# 19  https://images.genius.com/571780cc8959528e8166...
#
#    primary_artist.is_meme_verified primary_artist.is_verified  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# 5                            False                      False
# 6                            False                      False
# 7                            False                      False
# 8                            False                      False
# 9                            False                      False
# 10                           False                      False
# 11                           False                      False
# 12                           False                      False
# 13                           False                      False
# 14                           False                      False
# 15                           False                      False
# 16                           False                      False
# 17                           False                      False
# 18                           False                      False
# 19                           False                      False
#
#             primary_artist.name  \
# 0                USA For Africa
# 1                     Bob Dylan
# 2                         Adele
# 3                     Bob Dylan
# 4                     Bob Dylan
# 5                 Guns N’ Roses
# 6                     Bob Dylan
# 7                     Bob Dylan
# 8                     Bob Dylan
# 9   The Jimi Hendrix Experience
# 10                    Bob Dylan
# 11                    Bob Dylan
# 12                    Bob Dylan
# 13                    Bob Dylan
# 14                    Bob Dylan
# 15                Darius Rucker
# 16                    Bob Dylan
# 17                    Bob Dylan
# 18                    Bob Dylan
# 19                    Bob Dylan
#
#                                    primary_artist.url stats.concurrents
# 0           https://genius.com/artists/Usa-for-africa               NaN
# 1                https://genius.com/artists/Bob-dylan               NaN
# 2                    https://genius.com/artists/Adele               NaN
# 3                https://genius.com/artists/Bob-dylan               NaN
# 4                https://genius.com/artists/Bob-dylan               NaN
# 5             https://genius.com/artists/Guns-n-roses               NaN
# 6                https://genius.com/artists/Bob-dylan               NaN
# 7                https://genius.com/artists/Bob-dylan               NaN
# 8                https://genius.com/artists/Bob-dylan               NaN
# 9   https://genius.com/artists/The-jimi-hendrix-ex...               NaN
# 10               https://genius.com/artists/Bob-dylan               NaN
# 11               https://genius.com/artists/Bob-dylan               NaN
# 12               https://genius.com/artists/Bob-dylan               NaN
# 13               https://genius.com/artists/Bob-dylan               NaN
# 14               https://genius.com/artists/Bob-dylan               NaN
# 15           https://genius.com/artists/Darius-rucker               2.0
# 16               https://genius.com/artists/Bob-dylan               NaN
# 17               https://genius.com/artists/Bob-dylan               NaN
# 18               https://genius.com/artists/Bob-dylan               NaN
# 19               https://genius.com/artists/Bob-dylan               NaN
#
# [20 rows x 37 columns]

# %% [markdown]
# ## Problem 5
# ## Using the `lyricsgenius` library to download and display the lyrics to "Tangled Up in Blue" by Bob Dylan

# %% [markdown]
# Importing the package and initiating Genius:

# %%
import lyricsgenius
genius = lyricsgenius.Genius(genius_accesstoken)

# %% [markdown]
# Based on the usage instructions in the GitHub page, I can used the following syntax to search for single song for an artist: `song = genius.search_song("To You", artist.name)`:

# %%
song = genius.search_song("Tangled Up in Blue", "Bob Dylan")
print(song.lyrics)
# Out:
# Searching for "Tangled Up in Blue" by Bob Dylan...
# Done.
# 96 ContributorsTangled Up in Blue Lyrics[Verse 1]
# Early one morning the sun was shining
# I was laying in bed
# Wondering if she'd changed at all
# If her hair was still red
# Her folks they said our lives together
# Sure was going to be rough
# They never did like Mama's homemade dress
# Papa's bankbook wasn't big enough
# And I was standing on the side of the road
# Rain falling on my shoes
# Heading out for the East Coast
# Lord knows I've paid some dues
# Getting through
# Tangled up in blue
#
# [Verse 2]
# She was married when we first met
# Soon to be divorced
# I helped her out of a jam, I guess
# But I used a little too much force
# We drove that car as far as we could
# Abandoned it out west
# Split up on a dark sad night
# Both agreeing it was best
# She turned around to look at me
# As I was walking away
# I heard her say over my shoulder
# "We'll meet again someday
# On the avenue"
# Tangled up in blue
# See Bob Dylan LiveGet tickets as low as $24You might also like[Verse 3]
# I had a job in the great north woods
# Working as a cook for a spell
# But I never did like it all that much
# And one day the ax just fell
# So I drifted down to New Orleans
# Where I lucky was to be employed
# Working for a while on a fishing boat
# Right outside of Delacroix
# But all the while I was alone
# The past was close behind
# I seen a lot of women
# But she never escaped my mind
# And I just grew
# Tangled up in blue
#
# [Verse 4]
# She was working in a topless place
# And I stopped in for a beer
# I just kept looking at the side of her face
# In the spotlight, so clear
# And later on, when the crowd thinned out
# I was just about to do the same
# She was standing there, in back of my chair
# Said, "Tell me, don't I know your name?"
# I muttered something underneath my breath
# She studied the lines on my face
# I must admit, I felt a little uneasy
# When she bent down to tie the laces
# Of my shoe
# Tangled up in blue
# [Verse 5]
# She lit a burner on the stove
# And offered me a pipe
# "I thought you'd never say hello," she said
# "You look like the silent type"
# Then she opened up a book of poems
# And handed it to me
# Written by an Italian poet
# From the thirteenth century
# And every one of them words rang true
# And glowed like burning coal
# Pouring off of every page
# Like it was written in my soul
# From me to you
# Tangled up in blue
#
# [Verse 6]
# I lived with them on Montague Street
# In a basement down the stairs
# There was music in the cafes at night
# And revolution in the air
# Then he started into dealing with slaves
# And something inside of him died
# She had to sell everything she owned
# And froze up inside
# And when it finally, the bottom fell out
# I became withdrawn
# The only thing I knew how to do
# Was to keep on keeping on
# Like a bird that flew
# Tangled up in blue
# [Verse 7]
# So now I'm going back again
# I got to get to her somehow
# All the people we used to know
# They're an illusion to me now
# Some are mathematicians
# Some are carpenter's wives
# Don't know how it all got started
# I don't know what they're doing with their lives
# But me, I'm still on the road
# A-heading for another joint
# We always did feel the same
# We just saw it from a different point
# Of view
# Tangled up in blue26Embed
