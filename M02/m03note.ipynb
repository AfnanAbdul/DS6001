# %%
import numpy as np
import pandas as pd
import os
import sys
sys.tracebacklimit = 0 # turn off the error tracebacks

# %%
os.getcwd
oldpath = os.getcwd()
os.chdir("data")

# %%
anes = pd.read_csv("anes_example.csv")

# %%
pd.set_option('display.max_columns', 10) # display a max of 10 columns
pd.set_option('display.max_rows', 10) # display a max of 10 rows

# %%
anes
# Out:
#       caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 0        1.0          1         NaN     2.0        100  ...              2
# 1        2.0          2         NaN     NaN         50  ...              2
# 2        3.0          1         NaN     1.0        100  ...              2
# 3        4.0          1         NaN     2.0        100  ...              2
# 4        5.0          1         NaN     1.0        100  ...              2
# ...      ...        ...         ...     ...        ...  ...            ...
# 1195  1196.0          1         NaN     2.0        100  ...              2
# 1196  1197.0          1         NaN     1.0         80  ...              1
# 1197  1198.0          1         NaN     2.0         95  ...              2
# 1198  1199.0          1         NaN     2.0         80  ...              2
# 1199  1200.0          2         NaN     NaN          0  ...              2
#
#       pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# ...

# %%
anes.head(10)
# Out:
#    caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 0     1.0          1         NaN     2.0        100  ...              2
# 1     2.0          2         NaN     NaN         50  ...              2
# 2     3.0          1         NaN     1.0        100  ...              2
# 3     4.0          1         NaN     2.0        100  ...              2
# 4     5.0          1         NaN     1.0        100  ...              2
# 5     6.0          1         NaN     3.0        100  ...              2
# 6     7.0          1         NaN     3.0        100  ...              2
# 7     8.0          1         NaN     1.0        100  ...              2
# 8     NaN          1         NaN     1.0        100  ...              1
# 9    10.0          1         NaN     2.0        100  ...              1
#
#    pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# 0            6       NaN      __NA__                  2
# 1            4       2.0      __NA__                  1
# ...

# %%
anes.tail(10)
# Out:
#       caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 1190  1191.0          1         NaN     2.0        100  ...              2
# 1191  1192.0          1         NaN     2.0        100  ...              2
# 1192  1193.0          1         NaN     3.0        100  ...              2
# 1193  1194.0          1         NaN     2.0         53  ...              2
# 1194  1195.0          1         NaN     3.0         50  ...              1
# 1195  1196.0          1         NaN     2.0        100  ...              2
# 1196  1197.0          1         NaN     1.0         80  ...              1
# 1197  1198.0          1         NaN     2.0         95  ...              2
# 1198  1199.0          1         NaN     2.0         80  ...              2
# 1199  1200.0          2         NaN     NaN          0  ...              2
#
#       pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# 1190            5      12.0      __NA__                  1
# ...

# %%
pd.set_option('display.max_rows', None) #to see all the variables
anes.dtypes
# Out:
# caseid               float64
# turnout12              int64
# turnout12b           float64
# vote12               float64
# percent16              int64
# meet                   int64
# givefut                int64
# info                   int64
# march                  int64
# sign                   int64
# give12mo               int64
# compromise             int64
# ftobama              float64
# ftblack              float64
# ftwhite                int64
# fthisp               float64
# ftgay                float64
# ftjeb                float64
# fttrump              float64
# ftcarson             float64
# fthrc                float64
# ftrubio              float64
# ftcruz               float64
# ftsanders            float64
# ftfiorina            float64
# ftpolice             float64
# ftfem                float64
# fttrans              float64
# ftmuslim             float64
# ftsci                float64
# reg                    int64
# demcand                int64
# ...

# %%
pd.set_option('display.max_rows', 10)

# %%
pd.set_option('display.max_seq_items', None)

# %%
anes.columns
# Out:
# Index(['caseid', 'turnout12', 'turnout12b', 'vote12', 'percent16', 'meet',
#        'givefut', 'info', 'march', 'sign', 'give12mo', 'compromise', 'ftobama',
#        'ftblack', 'ftwhite', 'fthisp', 'ftgay', 'ftjeb', 'fttrump', 'ftcarson',
#        'fthrc', 'ftrubio', 'ftcruz', 'ftsanders', 'ftfiorina', 'ftpolice',
#        'ftfem', 'fttrans', 'ftmuslim', 'ftsci', 'reg', 'demcand', 'repcand',
#        'vote16jb', 'vote16bc', 'vote16tc', 'vote16mr', 'vote16dt', 'presjob',
#        'lazyb', 'lazyw', 'lazyh', 'lazym', 'violentb', 'violentw', 'violenth',
#        'violentm', 'econnow', 'econ12mo', 'pid1d', 'pid2d', 'pid1r', 'pid2r',
#        'pidstr', 'pidlean', 'lcself', 'lcd', 'lcr', 'lchc', 'lcbo', 'lcdt',
#        'lcmr', 'lctc', 'srv_spend', 'campfin', 'immig_legal', 'immig_numb',
#        'equalpay', 'parleave', 'crimespend', 'death', 'terror_worry',
#        'terror_12mo', 'terror_local', 'relig_bc', 'relig_bcstr', 'relig_srv',
# ...

# %%
anes.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 168 columns):
#  #    Column             Dtype
# ---   ------             -----
#  0    caseid             float64
#  1    turnout12          int64
#  2    turnout12b         float64
#  3    vote12             float64
#  4    percent16          int64
#  5    meet               int64
#  6    givefut            int64
#  7    info               int64
#  8    march              int64
#  9    sign               int64
#  10   give12mo           int64
#  11   compromise         int64
#  12   ftobama            float64
#  13   ftblack            float64
#  14   ftwhite            int64
#  15   fthisp             float64
#  16   ftgay              float64
#  17   ftjeb              float64
#  18   fttrump            float64
#  19   ftcarson           float64
#  20   fthrc              float64
#  21   ftrubio            float64
#  22   ftcruz             float64
#  23   ftsanders          float64
# ...

# %%
anes[['ftobama']].describe()
# Out:
#            ftobama
# count  1193.000000
# mean     50.442582
# std      54.350731
# min       0.000000
# 25%       5.000000
# 50%      54.000000
# 75%      87.000000
# max     998.000000

# %%
anes[['ftobama']].describe(percentiles = [.2, .4, .6, .8])
# Out:
#            ftobama
# count  1193.000000
# mean     50.442582
# std      54.350731
# min       0.000000
# 20%       3.000000
# 40%      31.000000
# 50%      54.000000
# 60%      70.000000
# 80%      90.000000
# max     998.000000

# %%
anes.describe(include="object")
# Out:
#          pid2d   pid2r other10_open race_other employ_t religpew_t
# count     1200    1199           94       1200     1200       1200
# unique      37      31           57          1        1         11
# top     __NA__  __NA__            0     __NA__   __NA__     __NA__
# freq      1159    1162           17       1200     1200       1188

# %%
url = "https://raw.githubusercontent.com/jkropko/DS-6001/master/localdata/anes_example_toplines.csv"
import requests
file = requests.get(url)
print(file.text[0:1000])
# Out:
# THIS IS THE ANES 2016 PILOT STUDY
# DOWNLOADED AND EDITED BY JON KROPKO
# WHO ALSO ADDED THESE LINES AT THE TOP OF THE DATA FILE
# TO ANNOY HIS STUDENTS
# ...

# %%
anes = pd.read_csv('anes_example_toplines.csv', header = 4)
anes
# Out:
#       caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 0        1.0          1         NaN     2.0        100  ...              2
# 1        2.0          2         NaN     NaN         50  ...              2
# 2        3.0          1         NaN     1.0        100  ...              2
# 3        4.0          1         NaN     2.0        100  ...              2
# 4        5.0          1         NaN     1.0        100  ...              2
# ...      ...        ...         ...     ...        ...  ...            ...
# 1195  1196.0          1         NaN     2.0        100  ...              2
# 1196  1197.0          1         NaN     1.0         80  ...              1
# 1197  1198.0          1         NaN     2.0         95  ...              2
# 1198  1199.0          1         NaN     2.0         80  ...              2
# 1199  1200.0          2         NaN     NaN          0  ...              2
#
#       pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# ...

# %%
file = "anes_example_missing.csv"
anes = pd.read_csv(file)
anes
# Out:
#       caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 0          1          1        -999       2        100  ...              2
# 1          2          2        -999    -999         50  ...              2
# 2          3          1        -999       1        100  ...              2
# 3          4          1        -999       2        100  ...              2
# 4          5          1        -999       1        100  ...              2
# ...      ...        ...         ...     ...        ...  ...            ...
# 1195    1196          1        -999       2        100  ...              2
# 1196    1197          1        -999       1         80  ...              1
# 1197    1198          1        -999       2         95  ...              2
# 1198    1199          1        -999       2         80  ...              2
# 1199    1200          2        -999    -999          0  ...              2
#
#       pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# ...

# %%
anes = pd.read_csv(file, na_values = -999)
anes
# Out:
#       caseid  turnout12  turnout12b  vote12  percent16  ...  pew_bornagain  \
# 0        1.0          1         NaN     2.0        100  ...              2
# 1        2.0          2         NaN     NaN         50  ...              2
# 2        3.0          1         NaN     1.0        100  ...              2
# 3        4.0          1         NaN     2.0        100  ...              2
# 4        5.0          1         NaN     1.0        100  ...              2
# ...      ...        ...         ...     ...        ...  ...            ...
# 1195  1196.0          1         NaN     2.0        100  ...              2
# 1196  1197.0          1         NaN     1.0         80  ...              1
# 1197  1198.0          1         NaN     2.0         95  ...              2
# 1198  1199.0          1         NaN     2.0         80  ...              2
# 1199  1200.0          2         NaN     NaN          0  ...              2
#
#       pew_churatd  religpew  religpew_t  ever_vs_12mo_rand
# ...

# %%
os.chdir(oldpath)
